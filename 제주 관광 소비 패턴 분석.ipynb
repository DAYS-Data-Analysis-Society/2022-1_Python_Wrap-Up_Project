# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rc('font',family='Malgun Gothic') # 한글 폰트 지정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 꺠짐 방지

# %%
pd.read_csv("제주특별자치도_개별관광(FIT)_증가에_따른_제주_관광객_소비패턴_변화_분석_BC카드_빅데이터_내국인관광객_20170216.csv")
# Out:
#          기준년월   관광객 유형 제주 대분류 제주 중분류     업종명 성별 연령대별   카드이용금액    카드이용건수   \
# 0      Sep-14  내국인 관광객   서귀포시    대륜동   농축수산품  여  50대  14434000        67
# 1      Sep-14  내국인 관광객   서귀포시    대륜동   농축수산품  남  50대  15119000        72
# 2      Sep-14  내국인 관광객   서귀포시    대륜동   농축수산품  여  40대   7609500        41
# 3      Sep-14  내국인 관광객   서귀포시    남원읍   농축수산품  남  50대   7092500        40
# 4      Sep-14  내국인 관광객   서귀포시    대륜동   농축수산품  남  40대   9098500        59
# ...       ...      ...    ...    ...     ... ..  ...       ...       ...
# 13141  Aug-16  내국인 관광객   서귀포시    남원읍      약국  남  30대    252900        43
# 13142  Aug-16  내국인 관광객   서귀포시    대륜동      약국  남  20대    276100        49
# 13143  Aug-16  내국인 관광객   서귀포시    대륜동  기타음료식품  남  30대    610850       118
# 13144  Aug-16  내국인 관광객   서귀포시    대륜동  기타음료식품  여  20대    416900        85
# 13145  Aug-16  내국인 관광객   서귀포시    대륜동  기타음료식품  여  50대     56200        12
#
#        건당이용금액     데이터기준일자
# 0      215433  2017-02-16
# 1      209986  2017-02-16
# ...

# %%
jeju = pd.read_csv("제주특별자치도_개별관광(FIT)_증가에_따른_제주_관광객_소비패턴_변화_분석_BC카드_빅데이터_내국인관광객_20170216.csv")

# %%
jeju
# Out:
#          기준년월   관광객 유형 제주 대분류 제주 중분류     업종명 성별 연령대별   카드이용금액    카드이용건수   \
# 0      Sep-14  내국인 관광객   서귀포시    대륜동   농축수산품  여  50대  14434000        67
# 1      Sep-14  내국인 관광객   서귀포시    대륜동   농축수산품  남  50대  15119000        72
# 2      Sep-14  내국인 관광객   서귀포시    대륜동   농축수산품  여  40대   7609500        41
# 3      Sep-14  내국인 관광객   서귀포시    남원읍   농축수산품  남  50대   7092500        40
# 4      Sep-14  내국인 관광객   서귀포시    대륜동   농축수산품  남  40대   9098500        59
# ...       ...      ...    ...    ...     ... ..  ...       ...       ...
# 13141  Aug-16  내국인 관광객   서귀포시    남원읍      약국  남  30대    252900        43
# 13142  Aug-16  내국인 관광객   서귀포시    대륜동      약국  남  20대    276100        49
# 13143  Aug-16  내국인 관광객   서귀포시    대륜동  기타음료식품  남  30대    610850       118
# 13144  Aug-16  내국인 관광객   서귀포시    대륜동  기타음료식품  여  20대    416900        85
# 13145  Aug-16  내국인 관광객   서귀포시    대륜동  기타음료식품  여  50대     56200        12
#
#        건당이용금액     데이터기준일자
# 0      215433  2017-02-16
# 1      209986  2017-02-16
# ...

# %%
jeju.head()
# Out:
#      기준년월   관광객 유형 제주 대분류 제주 중분류    업종명 성별 연령대별   카드이용금액    카드이용건수   건당이용금액  \
# 0  Sep-14  내국인 관광객   서귀포시    대륜동  농축수산품  여  50대  14434000        67  215433
# 1  Sep-14  내국인 관광객   서귀포시    대륜동  농축수산품  남  50대  15119000        72  209986
# 2  Sep-14  내국인 관광객   서귀포시    대륜동  농축수산품  여  40대   7609500        41  185598
# 3  Sep-14  내국인 관광객   서귀포시    남원읍  농축수산품  남  50대   7092500        40  177313
# 4  Sep-14  내국인 관광객   서귀포시    대륜동  농축수산품  남  40대   9098500        59  154212
#
#       데이터기준일자
# 0  2017-02-16
# 1  2017-02-16
# 2  2017-02-16
# 3  2017-02-16
# 4  2017-02-16

# %%
jeju.tail()
# Out:
#          기준년월   관광객 유형 제주 대분류 제주 중분류     업종명 성별 연령대별   카드이용금액    카드이용건수   \
# 13141  Aug-16  내국인 관광객   서귀포시    남원읍      약국  남  30대    252900        43
# 13142  Aug-16  내국인 관광객   서귀포시    대륜동      약국  남  20대    276100        49
# 13143  Aug-16  내국인 관광객   서귀포시    대륜동  기타음료식품  남  30대    610850       118
# 13144  Aug-16  내국인 관광객   서귀포시    대륜동  기타음료식품  여  20대    416900        85
# 13145  Aug-16  내국인 관광객   서귀포시    대륜동  기타음료식품  여  50대     56200        12
#
#        건당이용금액     데이터기준일자
# 13141    5881  2017-02-16
# 13142    5635  2017-02-16
# 13143    5177  2017-02-16
# 13144    4905  2017-02-16
# 13145    4683  2017-02-16

# %%
jeju.연령대별.value_counts().plot(kind='pie', autopct='%.2f%%')
# Out:
# <AxesSubplot:ylabel='연령대별'>

# %%
import matplotlib.pyplot as plt

ratio = [23.86, 27.12, 26.08, 22.94]
labels = ['20대', '30대', '40대', '50대']
explode = [0.05, 0.05, 0.05, 0.05]
plt.title('Age')

plt.pie(ratio, labels=labels, autopct='%.2f%%',startangle=180, counterclock=False, explode=explode, shadow=True)
plt.show()

# %%
plot = jeju.groupby(['업종명','성별'])['성별'].count().unstack('성별')
plot.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='업종명'>

# %%
plot = jeju.groupby(['업종명','연령대별'])['연령대별'].count().unstack('연령대별')
plot.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='업종명'>
