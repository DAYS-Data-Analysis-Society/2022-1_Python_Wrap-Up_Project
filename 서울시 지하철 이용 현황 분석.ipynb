# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.font_manager
# 폰트 설정
plt.rc('font', family='NanumGothic')
plt.rc('font', size =11)
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)

# %%
Subway = pd.read_csv('2022.csv', encoding = 'cp949')

# %%
Subway
# Out:
#            사용일자    호선명         역명  승차총승객수  하차총승객수      등록일자
# 0      20220512  우이신설선   4.19민주묘지    3617    3386  20220515
# 1      20220512    경원선         가능    7739    7469  20220515
# 2      20220512    8호선       가락시장    8331    9239  20220515
# 3      20220512    3호선       가락시장    9870    9774  20220515
# 4      20220512    경부선    가산디지털단지   19999   23258  20220515
# ...         ...    ...        ...     ...     ...       ...
# 23200  20220404    경원선         회룡   12293   12293  20220407
# 23201  20220404    4호선  회현(남대문시장)   22858   24358  20220407
# 23202  20220404    경의선      효창공원앞    3043    3279  20220407
# 23203  20220404    6호선      효창공원앞    7072    6605  20220407
# 23204  20220404    9호선  흑석(중앙대입구)    8770    8918  20220407
#
# [23205 rows x 6 columns]

# %%
Subway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23205 entries, 0 to 23204
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용일자    23205 non-null  int64
#  1   호선명     23205 non-null  object
#  2   역명      23205 non-null  object
#  3   승차총승객수  23205 non-null  int64
#  4   하차총승객수  23205 non-null  int64
#  5   등록일자    23205 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.1+ MB

# %%
Subway.isnull()
# Out:
#         사용일자    호선명     역명  승차총승객수  하차총승객수   등록일자
# 0      False  False  False   False   False  False
# 1      False  False  False   False   False  False
# 2      False  False  False   False   False  False
# 3      False  False  False   False   False  False
# 4      False  False  False   False   False  False
# ...      ...    ...    ...     ...     ...    ...
# 23200  False  False  False   False   False  False
# 23201  False  False  False   False   False  False
# 23202  False  False  False   False   False  False
# 23203  False  False  False   False   False  False
# 23204  False  False  False   False   False  False
#
# [23205 rows x 6 columns]

# %%
Subway = Subway.loc[(Subway['호선명'] == '2호선') | (Subway['호선명'] == '1호선')]

# %%
Subway
# Out:
#            사용일자  호선명            역명  승차총승객수  하차총승객수      등록일자
# 13     20220512  2호선            강남   88571   88898  20220515
# 19     20220512  2호선    강변(동서울터미널)   33278   30577  20220515
# 29     20220512  2호선          건대입구   38835   41431  20220515
# 61     20220512  2호선    교대(법원.검찰청)   37567   42778  20220515
# 63     20220512  2호선       구로디지털단지   63751   63712  20220515
# ...         ...  ...           ...     ...     ...       ...
# 23144  20220404  1호선  청량리(서울시립대입구)   19062   18819  20220407
# 23155  20220404  2호선    충정로(경기대입구)    9496   10024  20220407
# 23181  20220404  2호선           한양대   14476   16482  20220407
# 23184  20220404  2호선            합정   27205   28264  20220407
# 23189  20220404  2호선          홍대입구   45432   47362  20220407
#
# [2340 rows x 6 columns]

# %%
Subway = Subway.drop('하차총승객수', axis = 'columns')

# %%
Subway
# Out:
#            사용일자  호선명            역명  승차총승객수      등록일자
# 13     20220512  2호선            강남   88571  20220515
# 19     20220512  2호선    강변(동서울터미널)   33278  20220515
# 29     20220512  2호선          건대입구   38835  20220515
# 61     20220512  2호선    교대(법원.검찰청)   37567  20220515
# 63     20220512  2호선       구로디지털단지   63751  20220515
# ...         ...  ...           ...     ...       ...
# 23144  20220404  1호선  청량리(서울시립대입구)   19062  20220407
# 23155  20220404  2호선    충정로(경기대입구)    9496  20220407
# 23181  20220404  2호선           한양대   14476  20220407
# 23184  20220404  2호선            합정   27205  20220407
# 23189  20220404  2호선          홍대입구   45432  20220407
#
# [2340 rows x 5 columns]

# %%
Subway = Subway.drop('등록일자', axis = 'columns')

# %%
Subway
# Out:
#            사용일자  호선명            역명  승차총승객수
# 13     20220512  2호선            강남   88571
# 19     20220512  2호선    강변(동서울터미널)   33278
# 29     20220512  2호선          건대입구   38835
# 61     20220512  2호선    교대(법원.검찰청)   37567
# 63     20220512  2호선       구로디지털단지   63751
# ...         ...  ...           ...     ...
# 23144  20220404  1호선  청량리(서울시립대입구)   19062
# 23155  20220404  2호선    충정로(경기대입구)    9496
# 23181  20220404  2호선           한양대   14476
# 23184  20220404  2호선            합정   27205
# 23189  20220404  2호선          홍대입구   45432
#
# [2340 rows x 4 columns]

# %%
Subway = Subway.loc[Subway['사용일자'] <= 20220504]

# %%
Subway
# Out:
#            사용일자  호선명            역명  승차총승객수
# 4776   20220504  2호선            강남   92790
# 4782   20220504  2호선    강변(동서울터미널)   37214
# 4791   20220504  2호선          건대입구   42918
# 4823   20220504  2호선    교대(법원.검찰청)   37722
# 4826   20220504  2호선       구로디지털단지   65587
# ...         ...  ...           ...     ...
# 23144  20220404  1호선  청량리(서울시립대입구)   19062
# 23155  20220404  2호선    충정로(경기대입구)    9496
# 23181  20220404  2호선           한양대   14476
# 23184  20220404  2호선            합정   27205
# 23189  20220404  2호선          홍대입구   45432
#
# [1860 rows x 4 columns]

# %%
Subway = Subway.loc[(Subway['역명'] == '서울역') | (Subway['역명'] == '종로3가') | (Subway['역명'] == '종각') | (Subway['역명'] == '청량리(서울시립대입구)') | (Subway['역명'] == '동대문') | (Subway['역명'] == '홍대입구') | (Subway['역명'] == '성수') | (Subway['역명'] == '신촌') | (Subway['역명'] == '한양대') | (Subway['역명'] == '서초')]

# %%
Subway
# Out:
#            사용일자  호선명            역명  승차총승객수
# 4914   20220504  1호선           동대문   12152
# 5041   20220504  1호선           서울역   52571
# 5047   20220504  2호선            서초   23945
# 5062   20220504  2호선            성수   40880
# 5126   20220504  2호선            신촌   38373
# ...         ...  ...           ...     ...
# 23107  20220404  1호선            종각   31125
# 23108  20220404  1호선          종로3가   22588
# 23144  20220404  1호선  청량리(서울시립대입구)   19062
# 23181  20220404  2호선           한양대   14476
# 23189  20220404  2호선          홍대입구   45432
#
# [310 rows x 4 columns]

# %%
ff = Subway.loc[(Subway['역명'] == '서울역') | (Subway['역명'] == '종로3가') | (Subway['역명'] == '종각') | (Subway['역명'] == '청량리(서울시립대입구)') | (Subway['역명'] == '동대문')]

# %%
bb = Subway.loc[(Subway['역명'] == '홍대입구') | (Subway['역명'] == '성수') | (Subway['역명'] == '신촌') | (Subway['역명'] == '한양대') | (Subway['역명'] == '서초')]

# %%
ff
# Out:
#            사용일자  호선명            역명  승차총승객수
# 4914   20220504  1호선           동대문   12152
# 5041   20220504  1호선           서울역   52571
# 5260   20220504  1호선            종각   39812
# 5261   20220504  1호선          종로3가   28591
# 5297   20220504  1호선  청량리(서울시립대입구)   22469
# ...         ...  ...           ...     ...
# 22760  20220404  1호선           동대문   10189
# 22888  20220404  1호선           서울역   39136
# 23107  20220404  1호선            종각   31125
# 23108  20220404  1호선          종로3가   22588
# 23144  20220404  1호선  청량리(서울시립대입구)   19062
#
# [155 rows x 4 columns]

# %%
bb
# Out:
#            사용일자  호선명    역명  승차총승객수
# 5047   20220504  2호선    서초   23945
# 5062   20220504  2호선    성수   40880
# 5126   20220504  2호선    신촌   38373
# 5332   20220504  2호선   한양대   15636
# 5341   20220504  2호선  홍대입구   64057
# ...         ...  ...   ...     ...
# 22893  20220404  2호선    서초   20156
# 22908  20220404  2호선    성수   34919
# 22972  20220404  2호선    신촌   30264
# 23181  20220404  2호선   한양대   14476
# 23189  20220404  2호선  홍대입구   45432
#
# [155 rows x 4 columns]

# %%
ff['승차총승객수'].sum()
# Out:
# 3894407

# %%
bb['승차총승객수'].sum()
# Out:
# 4599781

# %%
gg = pd.DataFrame({'1호선': [3894407],
                   '2호선': [4599781]})

# %%
gg
# Out:
#        1호선      2호선
# 0  3894407  4599781

# %%
mm = gg.rename(index = {0 : '승차총승객수'})

# %%
mm
# Out:
#             1호선      2호선
# 승차총승객수  3894407  4599781

# %%
mm.plot(kind='bar')
plt.xticks(rotation = 360)
# Out:
# (array([0]), [Text(0, 0, '승차총승객수')])

# %%
mm
# Out:
#             1호선      2호선
# 승차총승객수  3894407  4599781

# %%
mm = mm.transpose()

# %%
mm
# Out:
#       승차총승객수
# 1호선  3894407
# 2호선  4599781

# %%
HH = pd.DataFrame({'역명':['1호선','2호선'],
                  '승차총승객수':[3894407,4599781]})

# %%
HH
# Out:
#     역명   승차총승객수
# 0  1호선  3894407
# 1  2호선  4599781

# %%
plt.axis('equal')
plt.pie(HH['승차총승객수'], labels = HH['역명'], autopct = '%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x19215ce26d0>,
# ...
#  [Text(0.14307965680063772, 1.0906549462638548, '1호선'),
#   Text(-0.14307975891512312, -1.0906549328677657, '2호선')],
#  [Text(0.0780434491639842, 0.5949026979621025, '45.8%'),
#   Text(-0.07804350486279442, -0.5949026906551448, '54.2%')])
